# %%
import duckdb

con = duckdb.connect("../data/market_analysis.duckdb")

con.sql("""
    COPY mart_event_study_ready
    TO '../data/processed/mart_event_study_ready.csv'
    (HEADER, DELIMITER ',')
""")

print("Export complete")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[15], line 5
#       1 import duckdb
#       2
#       3 con = duckdb.connect("../data/market_analysis.duckdb")
#       4
# ----> 5 con.sql("""
#       6     COPY mart_event_study_ready
#       7     TO '../data/processed/mart_event_study_ready.csv'
#       8     (HEADER, DELIMITER ',')
#
# IOException: IO Error: No files found that match the pattern "../../data/raw/market_prices.csv"

# %%
# Out:
# ---------------------------------------------------------------------------
# ParserException                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 con.sql("SHOW CREATE VIEW mart_event_study_ready").df()
#
# ParserException: Parser Error: syntax error at or near "CREATE"
#
# LINE 1: SHOW CREATE VIEW mart_event_study_ready
#              ^
